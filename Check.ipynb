# %%
import streamlit as st
import pandas as pd
import numpy as np
import plotly.express as px

# %%
# df = pd.read_excel(r"D:\Work for MWG\DataBase\Data Daily\PX/Chi_Tiet_Phieu_Xuat_21_06_2023.xlsx")
# df.to_feather("Data.feather")

# %%
df = pd.read_feather("Data.feather")
print(df.shape)
df.head(2)
# Out:
# (100000, 39)
#    Tổng số lượng cân/chia  sumcolumn_amounttotalall  Mã siêu thị
# 0             237234.8678                5214461658         6391  \
# 1             237234.8678                5214461658         7821
#
#                         Tên siêu thị      Mã phiếu xuất  Mã hình thức xuất
# 0  BHX_LAN_CGI - Thửa 675 Đông Thạnh  23060063910471407                  3  \
# 1    BHX_HCM_Q07 - 524B Lê Văn Lương  23060078210279727                  3
#
#             Ngày xuất    Mã sản phẩm             Tên sản phẩm    Mã Model
# 0 2023-06-21 17:08:00  1232854000064  TÁO FUJI MINI NHẬP KHẨU  2009000324  \
# 1 2023-06-21 12:50:00  1232854000064  TÁO FUJI MINI NHẬP KHẨU  2009000324
#
#    ... Mã cận date Chứng từ liên quan  Tổng trọng lượng
# 0  ...           0               None               0.0  \
# 1  ...           0               None               0.0
#
#                    note2      Tên hình thức xuất bán       Ngày đặt hàng
# ...

# %%
df_new = pd.concat([df]*100, ignore_index=True)

print(df_new.shape)
df_new.head(2)
# Out:
# (100000, 39)
#    Tổng số lượng cân/chia  sumcolumn_amounttotalall  Mã siêu thị
# 0             237234.8678                5214461658         6391  \
# 1             237234.8678                5214461658         7821
#
#                         Tên siêu thị      Mã phiếu xuất  Mã hình thức xuất
# 0  BHX_LAN_CGI - Thửa 675 Đông Thạnh  23060063910471407                  3  \
# 1    BHX_HCM_Q07 - 524B Lê Văn Lương  23060078210279727                  3
#
#             Ngày xuất    Mã sản phẩm             Tên sản phẩm    Mã Model
# 0 2023-06-21 17:08:00  1232854000064  TÁO FUJI MINI NHẬP KHẨU  2009000324  \
# 1 2023-06-21 12:50:00  1232854000064  TÁO FUJI MINI NHẬP KHẨU  2009000324
#
#    ... Mã cận date Chứng từ liên quan  Tổng trọng lượng
# 0  ...           0               None               0.0  \
# 1  ...           0               None               0.0
#
#                    note2      Tên hình thức xuất bán       Ngày đặt hàng
# ...

# %%
# df['Số lượng'] = np.where(df['Tên sản phẩm']=='TRÁI VẢI',df['Số lượng']*10,df['Số lượng'])

# %%
df_new.to_feather("Data.feather")

# %%
df = pd.read_feather("Data.feather")
print(df.shape)
df.head(2)
# Out:
# (10000000, 39)
#    Tổng số lượng cân/chia  sumcolumn_amounttotalall  Mã siêu thị
# 0             237234.8678                5214461658         6391  \
# 1             237234.8678                5214461658         7821
#
#                         Tên siêu thị      Mã phiếu xuất  Mã hình thức xuất
# 0  BHX_LAN_CGI - Thửa 675 Đông Thạnh  23060063910471407                  3  \
# 1    BHX_HCM_Q07 - 524B Lê Văn Lương  23060078210279727                  3
#
#             Ngày xuất    Mã sản phẩm             Tên sản phẩm    Mã Model
# 0 2023-06-21 17:08:00  1232854000064  TÁO FUJI MINI NHẬP KHẨU  2009000324  \
# 1 2023-06-21 12:50:00  1232854000064  TÁO FUJI MINI NHẬP KHẨU  2009000324
#
#    ... Mã cận date Chứng từ liên quan  Tổng trọng lượng
# 0  ...           0               None               0.0  \
# 1  ...           0               None               0.0
#
#                    note2      Tên hình thức xuất bán       Ngày đặt hàng
# ...
